# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_json("baikal_data.json")
print(f"Строк: {df.shape[0]}, Столбцов: {df.shape[1]}")
df.head()
# Out:
# Строк: 1100, Столбцов: 10
#    ID   Животное            Тип    Место наблюдения  Сезон  Количество особей  \
# 0   1      Омуль           рыба  Чивыркуйский залив  весна               83.0
# 1   2  Голомянка           рыба  Чивыркуйский залив  осень              224.0
# 2   3      Чайка          птица  Селенгинский район   зима                1.0
# 3   4      Нерпа  млекопитающее  Селенгинский район  осень                6.0
# 4   5      Чайка          птица              Ольхон  осень                3.0
#
#    Температура воздуха (°C) Тип питания Антропогенный фактор  \
# 0                 -5.945668    всеядный          загрязнение
# 1                  9.245049      хищник          загрязнение
# 2                -19.465447      хищник          нет влияния
# 3                 14.569795      хищник          загрязнение
# 4                 -3.955328      хищник          рыболовство
#
#                                      Интересный факт
# 0          Символ Байкала, нерестится в реках осенью
# 1     Уникальная живородящая рыба с прозрачным телом
# 2      Гнездится колониями на скалах, питается рыбой
# 3  Единственное млекопитающее Байкала, может ныря...
# 4      Гнездится колониями на скалах, питается рыбой

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1100 entries, 0 to 1099
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1100 non-null   int64
#  1   Животное                  1100 non-null   str
#  2   Тип                       1100 non-null   str
#  3   Место наблюдения          1100 non-null   str
#  4   Сезон                     1100 non-null   str
#  5   Количество особей         1099 non-null   float64
#  6   Температура воздуха (°C)  1097 non-null   float64
#  7   Тип питания               1100 non-null   str
#  8   Антропогенный фактор      1100 non-null   str
#  9   Интересный факт           1100 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 94.5 KB

# %% [markdown]
# #### Первое знакомство с данными
#   1. ID — Уникальный номер записи.
#   2. Животное — Вид животного.
#   3. Тип — Биологический класс/группа.
#   4. Место наблюдения — Локация встречи.
#   5. Сезон — Время года.
#   6. Количество особей — Число замеченных животных.
#   7. Температура воздуха (°C) — Температура при наблюдении.
#   8. Тип питания — Пищевая специализация.
#   9. Антропогенный фактор — Влияние человека.
#   10. Интересный факт — Особенность вида.

# %%
display(df.describe())
# Out:
#                 ID  Количество особей  Температура воздуха (°C)
# count  1100.000000        1099.000000               1097.000000
# mean    550.500000         985.754322                 -1.605929
# std     317.686953        2329.403210                 12.794733
# min       1.000000           0.000000                -24.932808
# 25%     275.750000           8.000000                -12.694100
# 50%     550.500000          85.000000                 -1.773593
# 75%     825.250000         330.500000                 10.296396
# max    1100.000000       14817.000000                 19.981301

# %%
float_data = ["ID", "Количество особей", "Температура воздуха (°C)"]
for col in float_data:
  categorical_data = []
  if df[col].shape[0] / len(df[col].unique()) < 0.01:
    categorical_data.append(col)
print(categorical_data)
# Out:
# []

# %% [markdown]
# #### Типы данных
#   1. String — Животное, Тип, Место наблюдения, Сезон, Тип питания, Антропогенный фактор, Интересный факт.
#   2. Float (Числовые) — Количество особей, Температура воздуха (°C).

# %%
print(f"Всего пропусков {int(df.isna().sum().sum())}")
# Out:
# Всего пропусков 4

# %%
def data_visualization(df, num_data):
  df_copy = df.copy()
  for i in df_copy
df.hist(df, bins = 40)
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.hist(df, bins = 40)
#       2 plt.imshow()
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/plotting/_core.py:258, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     168 """
#     169 Make a histogram of the DataFrame's columns.
#     170
#    (...)    255     >>> hist = df.hist(bins=3)
#     256 """
#     257 plot_backend = _get_plot_backend(backend)
# --> 258 return plot_backend.hist_frame(
#     259     data,
#     260     column=column,
#     261     by=by,
#     262     grid=grid,
#     263     xlabelsize=xlabelsize,
#     264     xrot=xrot,
#     265     ylabelsize=ylabelsize,
#     266     yrot=yrot,
#     267     ax=ax,
#     268     sharex=sharex,
#     269     sharey=sharey,
#     270     figsize=figsize,
#     271     layout=layout,
#     272     legend=legend,
#     273     bins=bins,
#     274     **kwargs,
#     275 )
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:537, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     535     if not isinstance(column, (list, np.ndarray, ABCIndex)):
#     536         column = [column]
# --> 537     data = data[column]
#     538 # GH32590
#     539 data = data.select_dtypes(
#     540     include=(np.number, "datetime64", "datetimetz"), exclude="timedelta"
#     541 )
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6297, in Index._get_indexer_strict(self, key, axis_name)
#    6294     keyarr = com.asarray_tuplesafe(keyarr)
#    6296 if self._index_as_unique:
# -> 6297     indexer = self.get_indexer_for(keyarr)
#    6298     keyarr = self.reindex(keyarr)[0]
#    6299 else:
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6284, in Index.get_indexer_for(self, target)
#    6254 """
#    6255 Guaranteed return of an indexer even when non-unique.
#    6256
#    (...)   6281 array([0, 2])
#    6282 """
#    6283 if self._index_as_unique:
# -> 6284     return self.get_indexer(target)
#    6285 indexer, _ = self.get_indexer_non_unique(target)
#    6286 return indexer
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3723, in Index.get_indexer(self, target, method, limit, tolerance)
#    3721 method = clean_reindex_fill_method(method)
#    3722 orig_target = target
# -> 3723 target = self._maybe_cast_listlike_indexer(target)
#    3725 self._check_indexing_method(method, limit, tolerance)
#    3727 if not self._index_as_unique:
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6833, in Index._maybe_cast_listlike_indexer(self, target)
#    6829 def _maybe_cast_listlike_indexer(self, target) -> Index:
#    6830     """
#    6831     Analogue to maybe_cast_indexer for get_indexer instead of get_loc.
#    6832     """
# -> 6833     target_index = ensure_index(target)
#    6834     if (
#    6835         not hasattr(target, "dtype")
#    6836         and self.dtype == object
#    (...)   6839         # If we started with a list-like, avoid inference to string dtype if self
#    6840         # is object dtype (coercing to string dtype will alter the missing values)
#    6841         target_index = Index(target, dtype=self.dtype)
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:7975, in ensure_index(index_like, copy)
#    7973         return Index(index_like, copy=copy, tupleize_cols=False)
#    7974 else:
# -> 7975     return Index(index_like, copy=copy)
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:580, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     577         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     579 try:
# --> 580     arr = sanitize_array(data, None, dtype=dtype, copy=bool(copy))
#     581 except ValueError as err:
#     582     if "index must be specified when data is not list-like" in str(err):
#
# File ~/Studies/Infographics/.venv/lib/python3.11/site-packages/pandas/core/construction.py:616, in sanitize_array(data, index, dtype, copy, allow_2d)
#     614 subarr = data
#     615 if data.dtype == object and infer_object:
# --> 616     subarr = lib.maybe_convert_objects(
#     617         data,
#     618         # Here we do not convert numeric dtypes, as if we wanted that,
#     619         #  numpy would have done it for us.
#     620         convert_numeric=False,
#     621         convert_non_numeric=True,
#     622         convert_to_nullable_dtype=False,
#     623         dtype_if_all_nat=np.dtype("M8[s]"),
#     624     )
#     625 elif data.dtype.kind == "U" and using_string_dtype():
#     626     from pandas.core.arrays.string_ import StringDtype
#
# File pandas/_libs/lib.pyx:2568, in pandas._libs.lib.maybe_convert_objects()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 3)
